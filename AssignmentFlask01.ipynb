# %% [markdown]
# ***Q1***

# %% [markdown]
# Flask is a micro web framework written in Python. It is designed to be lightweight and easy to use, allowing developers to quickly build web applications. Flask is known for its simplicity and flexibility, providing the basic tools needed to create web applications without imposing any particular architecture or design pattern.

# %% [markdown]
# Advantages:
#
#     Simplicity: he framework is designed to be easy to understand and doesn't impose strict architectural patterns, giving developers flexibility in designing their applications.

# %% [markdown]
#     It also  ligthweight,flexibility and main it easy to inegration with python

# %% [markdown]
# ***Q2***

# %% [markdown]
# ![image.png](attachment:1dde864d-1dc7-495c-88e6-775a7de9ef50.png)

# %% [markdown]
# ![image.png](attachment:379148f8-3af2-418a-978d-c937e536fa05.png)

# %% [markdown]
# ***Q3***

# %% [markdown]
# App routing in Flask refers to the process of defining URL routes and associating them with specific functions or views in your Flask application. Routing allows you to map incoming requests to appropriate handlers, which determine how the application responds to those requests.

# %% [markdown]
# ***Use app routes:***
#      It done many things like url mapping,requesting handling,restfull API design,etc. They provide a way to structure and organize our web application and define how it interacts with users and handles various types of requests.

# %% [markdown]
# ***Q4***

# %% [markdown]
# ![image.png](attachment:4f9691e5-0651-42b4-935c-f46fdc08e351.png)

# %% [markdown]
# ![image.png](attachment:ea9e3008-ca60-46fc-ab7b-b1956104c7e4.png)

# %% [markdown]
# ![image.png](attachment:a757fc25-8f2a-4fef-8ca3-92fb01ecfd6e.png)

# %% [markdown]
# ***Q5***

# %% [markdown]
# In Flask, the 'url_for()' function is used for URL building. The 'url_for()' function generates a URL for a given view function or endpoint by taking into account the defined routes in the Flask application.

# %% [markdown]
# ![image.png](attachment:7231278a-1358-4062-aa85-49cdcdad2997.png)
